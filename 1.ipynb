# %%
import numpy as np
import pandas as pd

# %%
input = pd.read_csv('./data/1_input', sep='   ', header=None)
# Out:
# /tmp/ipykernel_18944/3958920949.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   input = pd.read_csv('./data/1_input', sep='   ', header=None)

# %%
input.head()
# Out:
#        0      1
# 0  61967  56543
# 1  11022  54992
# 2  21268  29417
# 3  90452  95846
# 4  90728  95846

# %%
ids_1, ids_2 = input.values[:,0],input.values[:,1]

# %%
ids_1, ids_2 = np.sort(ids_1), np.sort(ids_2)

# %%
np.abs(ids_2 - ids_1).sum()
# Out:
# np.int64(2904518)

# %% [markdown]
# how often each number from the left list appears in the right list. Calculate a total similarity score by adding up each number in the left list after multiplying it by the number of times that number appears in the right list.

# %%
from collections import Counter

# %%
ids_1
# Out:
# array([10029, 10144, 10164, 10257, 10278, 10431, 10470, 10585, 10763,
#        10786, 10906, 10909, 10951, 11022, 11029, 11296, 11396, 11549,
#        11580, 11649, 11682, 11722, 11737, 11822, 11917, 11921, 11930,
#        11974, 12035, 12067, 12068, 12186, 12215, 12440, 12630, 12646,
#        12667, 12766, 13042, 13125, 13131, 13142, 13151, 13278, 13350,
#        13389, 13565, 13669, 13678, 13738, 13786, 13799, 13834, 13948,
#        14078, 14085, 14526, 14541, 14745, 14830, 14836, 14866, 15028,
#        15075, 15090, 15153, 15159, 15227, 15314, 15379, 15388, 15429,
#        15467, 15494, 15520, 15665, 15908, 15919, 15922, 15955, 15973,
#        16148, 16207, 16208, 16296, 16313, 16395, 16397, 16656, 16715,
#        16822, 16919, 16973, 17097, 17399, 17507, 17562, 17748, 18008,
#        18050, 18381, 18459, 18651, 18684, 18780, 18993, 19176, 19186,
#        19198, 19298, 19300, 19305, 19348, 19659, 19677, 19720, 19745,
# ...

# %%
counter_1, counter_2 = Counter(ids_1), Counter(ids_2)

# %%
np.sum([key * counter_2[key] for key in counter_1.keys()])
# Out:
# np.int64(18650129)
